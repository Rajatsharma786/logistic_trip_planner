# %%
import os
import requests
from bs4 import BeautifulSoup
from datetime import datetime
from dotenv import load_dotenv
import json, re
from typing import List, Dict, Any, Optional
from urllib.parse import quote
import pandas as pd
from datetime import datetime

# %%
END_POINTS = {
    "melbourne": {
        "lat": -37.81, "lon": 144.96,
        "weather_station_id": "IDV60901.95936",
        "fuel_search_suburb": "Melbourne"
    },
    "sydney": {
        "lat": -33.86, "lon": 151.20,
        "weather_station_id": "IDN60901.94768",
        "fuel_search_suburb": "Sydney"
    }
}

WAYPOINTS = {
    "Hume_Highway": {
        "albury": {
            "lat": -36.08, "lon": 146.91,
            "weather_station_id": "IDN60901.94925",
            "fuel_search_suburb": "Albury"
        },
        "goulburn": {
            "lat": -34.75, "lon": 149.71,
            "weather_station_id": "IDN60903.94926",
            "fuel_search_suburb": "Goulburn"
        }
    },
    "Inland_Route": {
        "shepparton": {
            "lat": -36.38, "lon": 145.40,
            "weather_station_id": "IDV60801.94875",
            "fuel_search_suburb": "Shepparton"
        },
        "dubbo": {
            "lat": -32.25, "lon": 148.61,
            "weather_station_id": "IDN60801.95719",
            "fuel_search_suburb": "Dubbo"
        }
    }
}
CSV_FILE_PATH = 'freight_data_hume_highway.csv'

# %%
def get_weather_data(station_id):
    """
    Fetches the latest weather observation data from a specific BoM station.
    """
    url = f"http://www.bom.gov.au/fwo/{station_id.split('.')[0]}/{station_id}.json"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    try:
        response = requests.get(url, headers=headers ,timeout=10)
        response.raise_for_status()
        data = response.json()
        latest_obs = data.get("observations", {}).get("data", [])[0]
        if not latest_obs:
            return {"error": "No observation data found."}
        return {
            "location": latest_obs.get("name"),
            "time_utc": latest_obs.get("aifstime_utc"),
            "temperature": latest_obs.get("air_temp"),
            "rainfall_since_9am": latest_obs.get("rain_trace"),
            "wind_speed_kmh": latest_obs.get("wind_spd_kmh"),
            "wind_direction": latest_obs.get("wind_dir"),
        }
    except requests.exceptions.RequestException as e:
        return {"error": f"Failed to fetch weather data: {e}"}
    except (KeyError, IndexError) as e:
        return {"error": f"Could not parse weather data structure: {e}"}

# %%
def get_traffic_data(bounding_box: str):
    TOMTOM_API_KEY = os.getenv("TOMTOM_API_KEY")
    if not TOMTOM_API_KEY:
        return {"error": "TomTom API key not found. Please check your .env file."}
    
    try:
        parts = [float(x) for x in bounding_box.split(",")]
        if len(parts) != 4:
            return {"error": "bbox must be 'west,south,east,north' with 4 numeric values."}
        west, south, east, north = parts
        if west >= east or south >= north:
            return {"error": "bbox order invalid. Expected west < east and south < north."}
    except Exception:
        return {"error": "bbox must be numeric like '144.90,-38.10,145.30,-37.60'."}

    base_url = "https://api.tomtom.com/traffic/services/5/incidentDetails"

    # Minimal valid projection (one line, no newlines or spaces)
    fields_raw = "{incidents{type,geometry{type,coordinates},properties{id,iconCategory,length,magnitudeOfDelay,delay,roadNumbers,from,to,events{description,code}}}}"
    fields_encoded = quote(fields_raw, safe="")

    url = (
        f"{base_url}?key={TOMTOM_API_KEY}"
        f"&bbox={bounding_box}"
        f"&fields={fields_encoded}"
        f"&language=en-GB"
        f"&timeValidityFilter=present"
    )

    try:
        resp = requests.get(url, timeout=20, headers={"Accept": "application/json"})
        resp.raise_for_status()
        data = resp.json()
    except requests.exceptions.HTTPError as e:
        sample_url = url.replace(TOMTOM_API_KEY, "****")  # mask key in error
        return {"error": f"Failed to fetch TomTom traffic data: {e}. url: {sample_url}"}
    except requests.exceptions.RequestException as e:
        return {"error": f"Network error contacting TomTom: {e}"}
    except Exception as e:
        return {"error": f"Unexpected error: {e}"}

    incidents_out = []
    for inc in data.get("incidents", []):
        props = inc.get("properties", {}) or {}
        events = props.get("events") or []
        desc = None
        if events and isinstance(events, list) and isinstance(events[0], dict):
            desc = events[0].get("description")
        incidents_out.append({
            "category": props.get("iconCategory"),
            "description": desc,
            "from": props.get("from"),
            "to": props.get("to"),
            "road_numbers": props.get("roadNumbers"),
            "incident_length_m":props.get("length"),
            "incident_delay":props.get("delay"),
            "incident_magnitude_delay":props.get("magnitudeOfDelay")
        })

    if not incidents_out:
        return {"status": "No incidents returned for this area."}

    return incidents_out

# %%
import requests
from typing import List, Tuple, Optional, Dict, Any

def get_travel_time_osrm(
    origin: Tuple[float, float],
    destination: Tuple[float, float],
    waypoints: Optional[List[Tuple[float, float]]] = None,
    *,
    optimize_order: bool = False,
    server: str = "https://router.project-osrm.org"
) -> Dict[str, Any]:
    """
    Compute driving time with OSRM. origin/waypoints/destination are (lat, lon).
    If optimize_order=True, uses OSRM's trip service (TSP) with fixed start & end.
    Returns seconds and per-leg durations; no live traffic.
    """
    coords = [origin] + (waypoints or []) + [destination]
    # OSRM expects lon,lat order
    lonlat = ";".join(f"{lon:.6f},{lat:.6f}" for lat, lon in coords)

    if optimize_order:
        # Fix start=first and end=last, let OSRM reorder the intermediates
        url = (f"{server}/trip/v1/driving/{lonlat}"
               "?source=first&destination=last&roundtrip=false&overview=false&steps=false")
        r = requests.get(url, timeout=20)
        r.raise_for_status()
        data = r.json()
        trips = data.get("trips", [])
        if not trips:
            return {"error": data.get("message", "No trip found")}
        trip = trips[0]
        legs = trip.get("legs", [])
        leg_secs = [int(leg.get("duration", 0)) for leg in legs]
        # Return OSRM's optimized order for the intermediates
        # waypoints[0] and waypoints[-1] are start/end; the rest have an "waypoint_index"
        optimized_order = []
        for wp in data.get("waypoints", []):
            if wp.get("trips_index", 0) == 0 and wp.get("waypoint_index") not in (0, len(coords)-1):
                optimized_order.append(wp["waypoint_index"] - 1)  # shift to 0-based among intermediates
        return {
            "total_duration_sec": int(trip.get("duration", 0)),
            "distance_meters": int(trip.get("distance", 0)),
            "leg_durations_sec": leg_secs,
            "num_waypoints": len(waypoints or []),
            "optimized_intermediate_order": sorted(optimized_order) or None
        }
    else:
        url = (f"{server}/route/v1/driving/{lonlat}"
               "?overview=false&steps=false&annotations=duration")
        r = requests.get(url, timeout=20)
        r.raise_for_status()
        data = r.json()
        routes = data.get("routes", [])
        if not routes:
            return {"error": data.get("message", "No route found")}
        route = routes[0]
        leg_secs = [int(leg.get("duration", 0)) for leg in route.get("legs", [])]
        return {
            "total_duration_sec": int(route.get("duration", 0)),
            "distance_meters": int(route.get("distance", 0)),
            "leg_durations_sec": leg_secs,
            "num_waypoints": len(waypoints or []),
            "optimized_intermediate_order": None
        }

# %%
if __name__ == "__main__":
    load_dotenv()
    print("--- Agentic AI Logistics Planner: Multi-Route Data Ingestion Script ---")
    print(f"--- Running at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')} ---\n")

    all_data = {}

    for route_name, route_wps in WAYPOINTS.items():
        print(f"\nFetching Data for: {route_name.replace('_',' ')}")
        print("=" * 40)
        all_data[route_name] = {}

        # lookup dict only (unordered is fine for lookups)
        full_route_locations = {**END_POINTS, **route_wps}

        # ordered node list for segment math
        node_names = ["melbourne"] + list(route_wps.keys()) + ["sydney"]

        # origin / intermediates / destination in declared order
        origin = (END_POINTS["melbourne"]["lat"], END_POINTS["melbourne"]["lon"])
        destination = (END_POINTS["sydney"]["lat"], END_POINTS["sydney"]["lon"])
        waypoints_list = [(route_wps[n]["lat"], route_wps[n]["lon"]) for n in route_wps.keys()]

        # ---- Free routing (OSRM public server). Fixed order; no traffic. ----
        coords = [origin] + waypoints_list + [destination]
        lonlat = ";".join(f"{lon:.6f},{lat:.6f}" for (lat, lon) in coords)
        osrm_url = f"https://router.project-osrm.org/route/v1/driving/{lonlat}?overview=false&steps=false"

        leg_secs, leg_dists = [], []
        route_travel = {}
        try:
            rr = requests.get(osrm_url, timeout=30)
            rr.raise_for_status()
            osrm = rr.json()
            routes = osrm.get("routes") or []
            if routes:
                route = routes[0]
                leg_secs  = [int(leg.get("duration", 0)) for leg in route.get("legs", [])]
                leg_dists = [int(leg.get("distance", 0)) for leg in route.get("legs", [])]
                route_travel = {
                    "total_duration_sec": int(route.get("duration", 0)),
                    "distance_meters": int(route.get("distance", 0)),
                    "leg_durations_sec": leg_secs,
                    "leg_distances_meters": leg_dists
                }
            else:
                route_travel = {"error": osrm.get("message", "No route returned")}
        except Exception as e:
            route_travel = {"error": f"OSRM call failed: {e}"}

        # cumulative time to each node
        cum_time = [0]
        for s in leg_secs:
            cum_time.append(cum_time[-1] + s)

        # ---- Per-location fetch + segment attachment ----
        for idx, loc_name in enumerate(node_names):
            print(f"  Processing Location: {loc_name.capitalize()}")
            cfg = full_route_locations[loc_name]
            lat, lon = cfg["lat"], cfg["lon"]

            bbox_size = 0.25
            min_lon, min_lat = lon - bbox_size, lat - bbox_size
            max_lon, max_lat = lon + bbox_size, lat + bbox_size
            location_bbox = f"{min_lon},{min_lat},{max_lon},{max_lat}"

            all_data[route_name][loc_name] = {}

            weather = get_weather_data(cfg["weather_station_id"])
            all_data[route_name][loc_name]["weather"] = weather

            traffic = get_traffic_data(location_bbox)
            all_data[route_name][loc_name]["traffic"] = traffic

            # segment info for this node
            inbound = None if idx == 0 else {
                "from": node_names[idx - 1],
                "to": loc_name,
                "duration_sec": leg_secs[idx - 1] if idx - 1 < len(leg_secs) else None,
                "distance_m":  leg_dists[idx - 1] if idx - 1 < len(leg_dists) else None,
            }
            outbound = None if idx == len(node_names) - 1 else {
                "from": loc_name,
                "to": node_names[idx + 1],
                "duration_sec": leg_secs[idx] if idx < len(leg_secs) else None,
                "distance_m":  leg_dists[idx] if idx < len(leg_dists) else None,
            }

            all_data[route_name][loc_name]["segment"] = {
                "inbound": inbound,
                "outbound": outbound,
                "cumulative_time_to_here_sec": cum_time[idx] if idx < len(cum_time) else None,
                "remaining_time_from_here_sec": (cum_time[-1] - cum_time[idx]) if idx < len(cum_time) else None,
            }

            # keep this for backward-compat with your processing
            all_data[route_name][loc_name]["route_travel"] = route_travel

        # route-level summary once
        all_data[route_name]["__route_summary__"] = {
            "total_duration_sec": route_travel.get("total_duration_sec"),
            "total_distance_meters": route_travel.get("distance_meters"),
            "num_waypoints": len(waypoints_list),
        }

    print("\n\n--- COMPLETE DATA PAYLOAD ---")
    print(json.dumps(all_data, indent=2))
# Out:
# --- Agentic AI Logistics Planner: Multi-Route Data Ingestion Script ---
# --- Running at: 2025-08-12 17:59:31 ---
#
#
# Fetching Data for: Hume Highway
# ========================================
#   Processing Location: Melbourne
#   Processing Location: Albury
#   Processing Location: Goulburn
#   Processing Location: Sydney
#
# Fetching Data for: Inland Route
# ========================================
#   Processing Location: Melbourne
#   Processing Location: Shepparton
#   Processing Location: Dubbo
#   Processing Location: Sydney
#
#
# --- COMPLETE DATA PAYLOAD ---
# {
#   "Hume_Highway": {
#     "melbourne": {
#       "weather": {
#         "location": "Melbourne (Olympic Park)",
#         "time_utc": "20250812073000",
#         "temperature": 10.8,
#         "rainfall_since_9am": "3.0",
#         "wind_speed_kmh": 13,
#         "wind_direction": "N"
#       },
#       "traffic": [
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Hacketts Road / Bowral Avenue",
#           "to": "Tamworth Grove",
#           "road_numbers": [],
#           "incident_length_m": 126.716,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Tamworth Grove",
#           "to": "Hacketts Road / Bowral Avenue",
#           "road_numbers": [],
#           "incident_length_m": 126.7158638324,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Gourlay Road (Melton Highway/C754)",
#           "to": "Plumpton Road (Melton Highway/C754)",
#           "road_numbers": [
#             "C754"
#           ],
#           "incident_length_m": 154.3674530958,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Maling Road",
#           "to": "Boundary Road",
#           "road_numbers": [],
#           "incident_length_m": 694.8238501959,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Boundary Road",
#           "to": "Maling Road",
#           "road_numbers": [],
#           "incident_length_m": 694.8238501959,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Mandalay Parade",
#           "to": "Taylors Road",
#           "road_numbers": [],
#           "incident_length_m": 208.0041427342,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Plumpton Road (Melton Highway/C754)",
#           "to": "Gourlay Road (Melton Highway/C754)",
#           "road_numbers": [
#             "C754"
#           ],
#           "incident_length_m": 1107.2189293774,
#           "incident_delay": 283,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "exit [12]",
#           "to": "Plumpton Road",
#           "road_numbers": [],
#           "incident_length_m": 184.0119730587,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Prosperity Street",
#           "to": "Leakes Road",
#           "road_numbers": [],
#           "incident_length_m": 74.1966522534,
#           "incident_delay": 61,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Diggers Rest",
#           "to": "Calder Freeway",
#           "road_numbers": [],
#           "incident_length_m": 157.4623384268,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "exit [12]",
#           "to": "Diggers Rest",
#           "road_numbers": [],
#           "incident_length_m": 202.5074097143,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Gourlay Road / The Parks",
#           "to": "Panorama Drive",
#           "road_numbers": [
#             "C754"
#           ],
#           "incident_length_m": 52.8623927844,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Queuing traffic",
#           "from": "Robinsons Road\"",
#           "to": "Western Freeway (M8)",
#           "road_numbers": [],
#           "incident_length_m": 725.2883671588,
#           "incident_delay": 197,
#           "incident_magnitude_delay": 2
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Christies Road (Deer Park Bypass/M8)",
#           "to": "Western Ring Road (Deer Park Bypass/M8)",
#           "road_numbers": [
#             "M8"
#           ],
#           "incident_length_m": 2304.1635331307,
#           "incident_delay": 88,
#           "incident_magnitude_delay": 1
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Princes Highway (Princes Freeway/M1)",
#           "to": "Geelong Road (Princes Freeway/M1)",
#           "road_numbers": [
#             "M1",
#             "21"
#           ],
#           "incident_length_m": 6534.0245673095,
#           "incident_delay": 326,
#           "incident_magnitude_delay": 1
#         },
#         {
#           "category": 6,
#           "description": "Queuing traffic",
#           "from": "Altona",
#           "to": "Burns Road",
#           "road_numbers": [],
#           "incident_length_m": 508.742895474,
#           "incident_delay": 139,
#           "incident_magnitude_delay": 2
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Fitzgerald Road (Boundary Road/S32)",
#           "to": "Western Ring Road (Boundary Road/S32)",
#           "road_numbers": [
#             "32"
#           ],
#           "incident_length_m": 507.6059038508,
#           "incident_delay": 110,
#           "incident_magnitude_delay": 1
#         },
#         {
#           "category": 6,
#           "description": "Queuing traffic",
#           "from": "Sunshine Avenue (Calder Freeway/M79)",
#           "to": "Green Gully Road (Calder Freeway/M79)",
#           "road_numbers": [
#             "M79"
#           ],
#           "incident_length_m": 2656.298425477,
#           "incident_delay": 214,
#           "incident_magnitude_delay": 2
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Bent Street",
#           "to": "Pier Street",
#           "road_numbers": [],
#           "incident_length_m": 109.3846971841,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Pier Street",
#           "to": "Bent Street",
#           "road_numbers": [],
#           "incident_length_m": 109.8498568951,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Melbourne Airport\"",
#           "to": "Melbourne Drive",
#           "road_numbers": [],
#           "incident_length_m": 30.4615927263,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 6,
#           "description": "Queuing traffic",
#           "from": "Melbourne Airport\"",
#           "to": "Melbourne Drive",
#           "road_numbers": [],
#           "incident_length_m": 254.1158558167,
#           "incident_delay": 155,
#           "incident_magnitude_delay": 2
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Raglan Street",
#           "to": "Military Road",
#           "road_numbers": [],
#           "incident_length_m": 29.9490360145,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Military Road",
#           "to": "Raglan Street",
#           "road_numbers": [],
#           "incident_length_m": 29.9490360145,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "exit [W7]",
#           "to": "exit [W6]",
#           "road_numbers": [],
#           "incident_length_m": 2223.9499865229,
#           "incident_delay": 38,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Roberts Road",
#           "to": "Harrington Road",
#           "road_numbers": [],
#           "incident_length_m": 317.3322065754,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Harrington Road",
#           "to": "Roberts Road",
#           "road_numbers": [],
#           "incident_length_m": 317.3322065754,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Mezzo Walk",
#           "to": "Strata Walk",
#           "road_numbers": [],
#           "incident_length_m": 42.8227490584,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Caroline Street",
#           "to": "Ramsay Street",
#           "road_numbers": [],
#           "incident_length_m": 239.7507391624,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Ramsay Street",
#           "to": "Caroline Street",
#           "road_numbers": [],
#           "incident_length_m": 239.7507391624,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "West Gate Tunnel / Dock Link Road",
#           "to": "Phillipps Road",
#           "road_numbers": [],
#           "incident_length_m": 306.2694879907,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Phillipps Road",
#           "to": "West Gate Tunnel / Dock Link Road",
#           "road_numbers": [],
#           "incident_length_m": 306.2694879907,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Loch Crescent",
#           "to": "Lebanon Street",
#           "road_numbers": [],
#           "incident_length_m": 144.1833174865,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Lebanon Street",
#           "to": "Loch Crescent",
#           "road_numbers": [],
#           "incident_length_m": 258.3495557594,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Lorimer Street (Salmon Street)",
#           "to": "Cook Street (Salmon Street)",
#           "road_numbers": [],
#           "incident_length_m": 12.6965541439,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Salmon Street / Caprice Avenue",
#           "to": "Douglas Street",
#           "road_numbers": [],
#           "incident_length_m": 216.7753772761,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Mills Place",
#           "to": "Lorimer Street / Park Crescent",
#           "road_numbers": [],
#           "incident_length_m": 63.4806985906,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Bridge closed",
#           "from": "Dudley Street (Wurundjeri Way)",
#           "to": "CityLink Tollway (Wurundjeri Way)",
#           "road_numbers": [],
#           "incident_length_m": 836.5022423915,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Craigieburn",
#           "to": "Summerhill Road",
#           "road_numbers": [],
#           "incident_length_m": 414.4907512071,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Bridge closed",
#           "from": "CityLink Tollway (Wurundjeri Way)",
#           "to": "Dudley Street (Wurundjeri Way)",
#           "road_numbers": [],
#           "incident_length_m": 1371.2085432471,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Summerhill Road",
#           "to": "Craigieburn",
#           "road_numbers": [],
#           "incident_length_m": 830.0202221971,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Brookville Drive",
#           "to": "Amaroo Road",
#           "road_numbers": [],
#           "incident_length_m": 47.7701107041,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Amaroo Road",
#           "to": "Brookville Drive",
#           "road_numbers": [],
#           "incident_length_m": 47.7701107041,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Kinloch Court",
#           "to": "Summerhill Road / Amaroo Road",
#           "road_numbers": [],
#           "incident_length_m": 1222.3515272154,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Summerhill Road / Amaroo Road",
#           "to": "Donnybrook Road (C723)",
#           "road_numbers": [],
#           "incident_length_m": 1402.8923619401,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Albion Street",
#           "to": "Garnet Street / Tinning Street",
#           "road_numbers": [],
#           "incident_length_m": 93.1513637578,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Capel Street",
#           "to": "Peel Street",
#           "road_numbers": [],
#           "incident_length_m": 24.1910294936,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Peel Street",
#           "to": "Queen Street",
#           "road_numbers": [],
#           "incident_length_m": 35.9729192618,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Boundary Road",
#           "to": "Sydney Road / Plaisted Street",
#           "road_numbers": [],
#           "incident_length_m": 287.3974942813,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Sydney Road / Plaisted Street",
#           "to": "Boundary Road",
#           "road_numbers": [],
#           "incident_length_m": 287.3974942813,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Elizabeth Street (Flinders Street/S30)",
#           "to": "St Kilda Road (Flinders Street/S30)",
#           "road_numbers": [
#             "30"
#           ],
#           "incident_length_m": 126.2326281345,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Russell Street (Flinders Street/S30)",
#           "to": "Elizabeth Street (Flinders Street/S30)",
#           "road_numbers": [
#             "30"
#           ],
#           "incident_length_m": 140.4989709001,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Park Street / Palmerston Crescent",
#           "to": "Bank Street",
#           "road_numbers": [],
#           "incident_length_m": 61.4739907312,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Heather Street (Park Street)",
#           "to": "St Kilda Road (Park Street)",
#           "road_numbers": [],
#           "incident_length_m": 217.6520740568,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Bank Street",
#           "to": "Park Street",
#           "road_numbers": [],
#           "incident_length_m": 138.9788848353,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Canterbury Road",
#           "to": "Park Street",
#           "road_numbers": [],
#           "incident_length_m": 87.107953704,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Harding Street",
#           "to": "Coburg",
#           "road_numbers": [],
#           "incident_length_m": 50.1761783938,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Park Street",
#           "to": "Canterbury Road",
#           "road_numbers": [],
#           "incident_length_m": 163.1664084962,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Park Street / Deakin Street",
#           "to": "Fitzroy Street",
#           "road_numbers": [],
#           "incident_length_m": 56.7317227438,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Mary Street",
#           "to": "Park Street / Deakin Street",
#           "road_numbers": [],
#           "incident_length_m": 56.7317227438,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Sunmoth Court",
#           "to": "Quarry Access Road",
#           "road_numbers": [],
#           "incident_length_m": 122.8727346754,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Quarry Access Road",
#           "to": "Sunmoth Court",
#           "road_numbers": [],
#           "incident_length_m": 122.8727346754,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Queens Parade / Wellington Street",
#           "to": "Fitzroy North",
#           "road_numbers": [],
#           "incident_length_m": 95.5674605316,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Queuing traffic",
#           "from": "Hoddle Street (Punt Road/S29)",
#           "to": "Swan Street (Punt Road/S29)",
#           "road_numbers": [
#             "29"
#           ],
#           "incident_length_m": 603.1840272747,
#           "incident_delay": 175,
#           "incident_magnitude_delay": 2
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "City\"",
#           "to": "Alexandra Parade",
#           "road_numbers": [
#             "M3"
#           ],
#           "incident_length_m": 359.4302159886,
#           "incident_delay": 67,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Craigieburn Road (Craigieburn Bypass/M31)",
#           "to": "Northern Ring Road (Hume Freeway/M31)",
#           "road_numbers": [
#             "M31"
#           ],
#           "incident_length_m": 4334.079178915,
#           "incident_delay": 213,
#           "incident_magnitude_delay": 1
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "High Street",
#           "to": "High Street",
#           "road_numbers": [],
#           "incident_length_m": 121.0009694414,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "High Street",
#           "to": "High Street / Railway Road",
#           "road_numbers": [],
#           "incident_length_m": 121.0009694414,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "High Street",
#           "to": "Cooper Street",
#           "road_numbers": [],
#           "incident_length_m": 191.0272939377,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Cooper Street",
#           "to": "High Street",
#           "road_numbers": [],
#           "incident_length_m": 191.0272939377,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Duffy Street",
#           "to": "High Street (C729)",
#           "road_numbers": [],
#           "incident_length_m": 106.3804588442,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Epping Road (High Street)",
#           "to": "Memorial Avenue (High Street)",
#           "road_numbers": [
#             "C729"
#           ],
#           "incident_length_m": 454.1497163158,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Epping Road (C729) / Hayston Boulevard",
#           "to": "Kyabram Street",
#           "road_numbers": [],
#           "incident_length_m": 90.6653519781,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Kyabram Street",
#           "to": "Epping Road (C729) / Hayston Boulevard",
#           "road_numbers": [],
#           "incident_length_m": 90.7787887796,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Champions Parade",
#           "to": "Epping Road (C729)",
#           "road_numbers": [],
#           "incident_length_m": 367.8231668813,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Matilda Avenue",
#           "to": "Epping Road (C729)",
#           "road_numbers": [],
#           "incident_length_m": 45.173621142,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Centre Road",
#           "to": "Beths Street",
#           "road_numbers": [],
#           "incident_length_m": 103.898707832,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Athelstan Road",
#           "to": "Bowen Street",
#           "road_numbers": [],
#           "incident_length_m": 18.9380463977,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Mckimmies Road (Plenty Road/S27)",
#           "to": "Metropolitan Ring Road (Plenty Road/S27)",
#           "road_numbers": [
#             "27"
#           ],
#           "incident_length_m": 842.7013224734,
#           "incident_delay": 157,
#           "incident_magnitude_delay": 1
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Manningham Road (Bulleen Road/S52)",
#           "to": "Eastern Freeway (Bulleen Road/S52)",
#           "road_numbers": [
#             "52"
#           ],
#           "incident_length_m": 474.7179365486,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Main Street",
#           "to": "Albert Street",
#           "road_numbers": [],
#           "incident_length_m": 46.5031012707,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Albert Street",
#           "to": "Main Street",
#           "road_numbers": [],
#           "incident_length_m": 136.4301882171,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Main Street",
#           "to": "Albert Street",
#           "road_numbers": [],
#           "incident_length_m": 63.0332023728,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Warrigal Road Exit",
#           "to": "Monash Freeway (M1)",
#           "road_numbers": [],
#           "incident_length_m": 372.337912897,
#           "incident_delay": 142,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Grimshaw Street",
#           "to": "Nell Street",
#           "road_numbers": [],
#           "incident_length_m": 172.8910486242,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Nell Street",
#           "to": "Grimshaw Street",
#           "road_numbers": [],
#           "incident_length_m": 278.6881345591,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Riversdale Road",
#           "to": "Green Street",
#           "road_numbers": [],
#           "incident_length_m": 281.9750346271,
#           "incident_delay": 272,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Kingston Road",
#           "to": "Henry Street",
#           "road_numbers": [],
#           "incident_length_m": 107.4345178656,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Henry Street",
#           "to": "Kingston Road",
#           "road_numbers": [],
#           "incident_length_m": 107.4345178656,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Old Dandenong Road",
#           "to": "Kingston Road",
#           "road_numbers": [],
#           "incident_length_m": 116.3560689805,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Corrigan Street",
#           "to": "Highbury Road",
#           "road_numbers": [],
#           "incident_length_m": 111.5159569072,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Highbury Road",
#           "to": "Corrigan Street",
#           "road_numbers": [],
#           "incident_length_m": 111.5159569072,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Beaconsfield Road",
#           "to": "Para Road",
#           "road_numbers": [],
#           "incident_length_m": 96.7848347757,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Para Road",
#           "to": "Beaconsfield Road",
#           "road_numbers": [],
#           "incident_length_m": 200.6243350488,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Bayside Avenue",
#           "to": "Edithvale",
#           "road_numbers": [],
#           "incident_length_m": 354.7576678582,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Edithvale",
#           "to": "Berry Avenue",
#           "road_numbers": [],
#           "incident_length_m": 417.8231473639,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Link Road",
#           "to": "Clayton Road",
#           "road_numbers": [],
#           "incident_length_m": 48.2345316141,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Tram Road",
#           "to": "Doncaster Road / Clay Drive",
#           "road_numbers": [],
#           "incident_length_m": 87.4447395738,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Doncaster Road / Clay Drive",
#           "to": "Tram Road",
#           "road_numbers": [],
#           "incident_length_m": 87.4447395738,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Milne Street",
#           "to": "Anderson Street",
#           "road_numbers": [],
#           "incident_length_m": 225.4091738201,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Anderson Street",
#           "to": "Milne Street",
#           "road_numbers": [],
#           "incident_length_m": 225.4091738201,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Seaford Road (Frankston Freeway/S11)",
#           "to": "Thames Promenade (Mornington Peninsula Freeway Sbnd/S11)",
#           "road_numbers": [
#             "M11"
#           ],
#           "incident_length_m": 3410.5823988027,
#           "incident_delay": 212,
#           "incident_magnitude_delay": 1
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Woodlea Drive / Ferntree Gully Road",
#           "to": "Monash Freeway (M1)",
#           "road_numbers": [],
#           "incident_length_m": 334.1390269716,
#           "incident_delay": 149,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Carramar Avenue",
#           "to": "Kingsway",
#           "road_numbers": [],
#           "incident_length_m": 368.729599303,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Springvale Road",
#           "to": "Carramar Avenue",
#           "road_numbers": [],
#           "incident_length_m": 380.9321425337,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Cootamundra Drive",
#           "to": "Meadowbrook Drive",
#           "road_numbers": [],
#           "incident_length_m": 117.3220374734,
#           "incident_delay": 244,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Monash Freeway (M1)",
#           "to": "Monash Freeway Nbnd / Monash Freeway (M1)",
#           "road_numbers": [],
#           "incident_length_m": 181.5316461661,
#           "incident_delay": 36,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "City\"",
#           "to": "Monash Freeway (M1)",
#           "road_numbers": [],
#           "incident_length_m": 803.9671522384,
#           "incident_delay": 227,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Stud Road (Monash Freeway/M1)",
#           "to": "Warrigal Road (Monash Freeway/M1)",
#           "road_numbers": [
#             "M1"
#           ],
#           "incident_length_m": 13077.4006690948,
#           "incident_delay": 493,
#           "incident_magnitude_delay": 1
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "South Gippsland Freeway (Monash Freeway/M1)",
#           "to": "EastLink (Monash Freeway/M1)",
#           "road_numbers": [
#             "M1"
#           ],
#           "incident_length_m": 4386.9477190422,
#           "incident_delay": 114,
#           "incident_magnitude_delay": 1
#         }
#       ],
#       "segment": {
#         "inbound": null,
#         "outbound": {
#           "from": "melbourne",
#           "to": "albury",
#           "duration_sec": 13826,
#           "distance_m": 313516
#         },
#         "cumulative_time_to_here_sec": 0,
#         "remaining_time_from_here_sec": 37560
#       },
#       "route_travel": {
#         "total_duration_sec": 37561,
#         "distance_meters": 867226,
#         "leg_durations_sec": [
#           13826,
#           14950,
#           8784
#         ],
#         "leg_distances_meters": [
#           313516,
#           357845,
#           195864
#         ]
#       }
#     },
#     "albury": {
#       "weather": {
#         "error": "Failed to fetch weather data: 404 Client Error: Not Found for url: http://www.bom.gov.au/fwo/IDN60901/IDN60901.94925.json"
#       },
#       "traffic": [
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Hereford Street",
#           "to": "Parkland Drive",
#           "road_numbers": [],
#           "incident_length_m": 214.795,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Parkland Drive",
#           "to": "Hereford Street",
#           "road_numbers": [],
#           "incident_length_m": 214.3378010954,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         }
#       ],
#       "segment": {
#         "inbound": {
#           "from": "melbourne",
#           "to": "albury",
#           "duration_sec": 13826,
#           "distance_m": 313516
#         },
#         "outbound": {
#           "from": "albury",
#           "to": "goulburn",
#           "duration_sec": 14950,
#           "distance_m": 357845
#         },
#         "cumulative_time_to_here_sec": 13826,
#         "remaining_time_from_here_sec": 23734
#       },
#       "route_travel": {
#         "total_duration_sec": 37561,
#         "distance_meters": 867226,
#         "leg_durations_sec": [
#           13826,
#           14950,
#           8784
#         ],
#         "leg_distances_meters": [
#           313516,
#           357845,
#           195864
#         ]
#       }
#     },
#     "goulburn": {
#       "weather": {
#         "location": "Canberra",
#         "time_utc": "20250812073000",
#         "temperature": 11.0,
#         "rainfall_since_9am": "0.0",
#         "wind_speed_kmh": 11,
#         "wind_direction": "NNW"
#       },
#       "traffic": [
#         {
#           "category": 7,
#           "description": "Contraflow",
#           "from": "Collector Road (Hume Highway/31)",
#           "to": "Wollogorang Road (Hume Highway/31)",
#           "road_numbers": [
#             "M31"
#           ],
#           "incident_length_m": 4471.32,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Wollogorang Road (Hume Highway/31)",
#           "to": "Collector Road (Hume Highway/31)",
#           "road_numbers": [
#             "M31"
#           ],
#           "incident_length_m": 3805.5868424358,
#           "incident_delay": 213,
#           "incident_magnitude_delay": 1
#         },
#         {
#           "category": 7,
#           "description": "Contraflow",
#           "from": "Wollogorang Road (Hume Highway/31)",
#           "to": "Collector Road (Hume Highway/31)",
#           "road_numbers": [
#             "M31"
#           ],
#           "incident_length_m": 4096.5637619185,
#           "incident_delay": 217,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Collector Road (Hume Highway/31)",
#           "to": "Wollogorang Road (Hume Highway/31)",
#           "road_numbers": [
#             "M31"
#           ],
#           "incident_length_m": 4296.7464486107,
#           "incident_delay": 106,
#           "incident_magnitude_delay": 1
#         }
#       ],
#       "segment": {
#         "inbound": {
#           "from": "albury",
#           "to": "goulburn",
#           "duration_sec": 14950,
#           "distance_m": 357845
#         },
#         "outbound": {
#           "from": "goulburn",
#           "to": "sydney",
#           "duration_sec": 8784,
#           "distance_m": 195864
#         },
#         "cumulative_time_to_here_sec": 28776,
#         "remaining_time_from_here_sec": 8784
#       },
#       "route_travel": {
#         "total_duration_sec": 37561,
#         "distance_meters": 867226,
#         "leg_durations_sec": [
#           13826,
#           14950,
#           8784
#         ],
#         "leg_distances_meters": [
#           313516,
#           357845,
#           195864
#         ]
#       }
#     },
#     "sydney": {
#       "weather": {
#         "location": "Sydney - Observatory Hill",
#         "time_utc": "20250812073000",
#         "temperature": 14.6,
#         "rainfall_since_9am": "0.0",
#         "wind_speed_kmh": 9,
#         "wind_direction": "S"
#       },
#       "traffic": [
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "M2 Motorway (Old Windsor Road)",
#           "to": "Caroline Chisholm Drive (Old Windsor Road)",
#           "road_numbers": [
#             "A40"
#           ],
#           "incident_length_m": 789.169,
#           "incident_delay": 136,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Merrylands Road (Jersey Road/A28)",
#           "to": "Great Western Highway (Emert Street/A28)",
#           "road_numbers": [
#             "A28"
#           ],
#           "incident_length_m": 948.5992605034,
#           "incident_delay": 135,
#           "incident_magnitude_delay": 1
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "New Illawarra Road (Heathcote Road)",
#           "to": "Macarthur Drive (Heathcote Road)",
#           "road_numbers": [],
#           "incident_length_m": 239.129662262,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Hainsworth Street",
#           "to": "Park Avenue",
#           "road_numbers": [],
#           "incident_length_m": 224.0327998853,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Queuing traffic",
#           "from": "Carlton Street (Bold Street)",
#           "to": "Parramatta Road (Bold Street)",
#           "road_numbers": [],
#           "incident_length_m": 200.1278665313,
#           "incident_delay": 109,
#           "incident_magnitude_delay": 2
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Parramatta Road (A44) / Wentworth Street",
#           "to": "Parramatta Road (A44) / Wentworth Street",
#           "road_numbers": [],
#           "incident_length_m": 135.7885374472,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Parramatta Road (A44)",
#           "to": "Parramatta Road (A44)",
#           "road_numbers": [],
#           "incident_length_m": 127.3777230746,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Parramatta Road (A44)",
#           "to": "Parramatta Road (A44)",
#           "road_numbers": [],
#           "incident_length_m": 127.3777230746,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Parramatta Road (A44) / Wentworth Street",
#           "to": "Parramatta Road (A44) / Wentworth Street",
#           "road_numbers": [],
#           "incident_length_m": 135.7885374472,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Belmore Street E",
#           "to": "Anne Street",
#           "road_numbers": [],
#           "incident_length_m": 177.8229582928,
#           "incident_delay": 244,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Clements Avenue",
#           "to": "Canterbury Road (A34) / Exceller Avenue",
#           "road_numbers": [],
#           "incident_length_m": 99.6008301929,
#           "incident_delay": 336,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Chapel Road",
#           "to": "Jacobs Street",
#           "road_numbers": [],
#           "incident_length_m": 136.5013126722,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Jacobs Street",
#           "to": "North Terrace",
#           "road_numbers": [],
#           "incident_length_m": 116.5673094707,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Queuing traffic",
#           "from": "Hall Street (St Hillers Road/A6)",
#           "to": "Parramatta Road (St Hillers Road/A6)",
#           "road_numbers": [
#             "A6"
#           ],
#           "incident_length_m": 482.6150662166,
#           "incident_delay": 141,
#           "incident_magnitude_delay": 2
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Canning Street",
#           "to": "Uhrig Road",
#           "road_numbers": [],
#           "incident_length_m": 67.1996259854,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Norfolk Road (Roberts Road/A3)",
#           "to": "Weeroona Road (Centenary Drive/A3)",
#           "road_numbers": [
#             "A3"
#           ],
#           "incident_length_m": 1160.4428919138,
#           "incident_delay": 196,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Liverpool Road (A22)",
#           "to": "Roberts Road (A3)",
#           "road_numbers": [],
#           "incident_length_m": 570.0153999348,
#           "incident_delay": 96,
#           "incident_magnitude_delay": 1
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Dean Street",
#           "to": "Liverpool Road (A22)",
#           "road_numbers": [],
#           "incident_length_m": 291.6795300002,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Fifth Avenue",
#           "to": "Sixth Avenue",
#           "road_numbers": [],
#           "incident_length_m": 144.1516846534,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Sixth Avenue",
#           "to": "Fifth Avenue",
#           "road_numbers": [],
#           "incident_length_m": 144.5310927269,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Bassett Street",
#           "to": "King Georges Road (A3)",
#           "road_numbers": [],
#           "incident_length_m": 117.2415284617,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Wandella Road",
#           "to": "Barkduk Avenue",
#           "road_numbers": [],
#           "incident_length_m": 261.0561077729,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
# ...
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Jacobs Street",
#           "to": "North Terrace",
#           "road_numbers": [],
#           "incident_length_m": 116.5673094707,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Queuing traffic",
#           "from": "Hall Street (St Hillers Road/A6)",
#           "to": "Parramatta Road (St Hillers Road/A6)",
#           "road_numbers": [
#             "A6"
#           ],
#           "incident_length_m": 482.6150662166,
#           "incident_delay": 141,
#           "incident_magnitude_delay": 2
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Canning Street",
#           "to": "Uhrig Road",
#           "road_numbers": [],
#           "incident_length_m": 67.1996259854,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Norfolk Road (Roberts Road/A3)",
#           "to": "Weeroona Road (Centenary Drive/A3)",
#           "road_numbers": [
#             "A3"
#           ],
#           "incident_length_m": 1160.4428919138,
#           "incident_delay": 196,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 6,
#           "description": "Slow traffic",
#           "from": "Liverpool Road (A22)",
#           "to": "Roberts Road (A3)",
#           "road_numbers": [],
#           "incident_length_m": 570.0153999348,
#           "incident_delay": 96,
#           "incident_magnitude_delay": 1
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Dean Street",
#           "to": "Liverpool Road (A22)",
#           "road_numbers": [],
#           "incident_length_m": 291.6795300002,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Fifth Avenue",
#           "to": "Sixth Avenue",
#           "road_numbers": [],
#           "incident_length_m": 144.1516846534,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Sixth Avenue",
#           "to": "Fifth Avenue",
#           "road_numbers": [],
#           "incident_length_m": 144.5310927269,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Bassett Street",
#           "to": "King Georges Road (A3)",
#           "road_numbers": [],
#           "incident_length_m": 117.2415284617,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Wandella Road",
#           "to": "Barkduk Avenue",
#           "road_numbers": [],
#           "incident_length_m": 261.0561077729,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "The Boulevarde",
#           "to": "Kingsway",
#           "road_numbers": [],
#           "incident_length_m": 9.9782300377,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Wandella Road",
#           "to": "Kiora Road",
#           "road_numbers": [],
#           "incident_length_m": 320.0416586215,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Dunkirk Avenue",
#           "to": "William Street",
#           "road_numbers": [],
#           "incident_length_m": 112.1924011101,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "William Street",
#           "to": "Dunkirk Avenue",
#           "road_numbers": [],
#           "incident_length_m": 112.1924011101,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Church Lane",
#           "to": "Russell Lane",
#           "road_numbers": [],
#           "incident_length_m": 180.7452476405,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Russell Lane",
#           "to": "Church Lane",
#           "road_numbers": [],
#           "incident_length_m": 180.7452476405,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Edgeworth David Avenue (Sydney-Newcastle Freeway/M1)",
#           "to": "M2 Motorway (Sydney-Newcastle Freeway/M1)",
#           "road_numbers": [
#             "M11"
#           ],
#           "incident_length_m": 8044.2874738866,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Thomas Street (Frederick Street)",
#           "to": "Elizabeth Street (Frederick Street)",
#           "road_numbers": [],
#           "incident_length_m": 35.7564889715,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Frederick Street",
#           "to": "Etonville Parade",
#           "road_numbers": [],
#           "incident_length_m": 24.4802093963,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Liverpool Road (Elizabeth Street)",
#           "to": "Frederick Street (Elizabeth Street)",
#           "road_numbers": [],
#           "incident_length_m": 145.8039427922,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Parramatta Road (Frederick Street)",
#           "to": "Thomas Street (Frederick Street)",
#           "road_numbers": [],
#           "incident_length_m": 868.6009493911,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Parramatta Road (Frederick Street)",
#           "to": "Elizabeth Street (Frederick Street)",
#           "road_numbers": [],
#           "incident_length_m": 223.3295054241,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Harriet Street",
#           "to": "Myrtle Street / Victoria Road",
#           "road_numbers": [],
#           "incident_length_m": 88.9926706381,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Refinery Drive / Tambua Street",
#           "to": "Jones Street",
#           "road_numbers": [],
#           "incident_length_m": 79.4355373345,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Jones Street",
#           "to": "Western Distributor Freeway (A4) / Bank Street",
#           "road_numbers": [],
#           "incident_length_m": 79.4355373345,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "George Street",
#           "to": "Pitt Street",
#           "road_numbers": [],
#           "incident_length_m": 4.1539080019,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Margaret Street (George Street)",
#           "to": "Bridge Street (George Street)",
#           "road_numbers": [],
#           "incident_length_m": 175.4608780835,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Pitt Street (Hunter Street)",
#           "to": "Little Hunter Street (Hunter Street)",
#           "road_numbers": [],
#           "incident_length_m": 31.957746524,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "George Street (Hunter Street)",
#           "to": "Pitt Street (Hunter Street)",
#           "road_numbers": [],
#           "incident_length_m": 73.5145077219,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Reiby Place",
#           "to": "Custom House Lane",
#           "road_numbers": [],
#           "incident_length_m": 23.8100497877,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Berry Street (Bradfield Highway/2)",
#           "to": "Mount Street (Bradfield Highway/2)",
#           "road_numbers": [],
#           "incident_length_m": 53.8237301811,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Sailors Bay Road",
#           "to": "Kiola Road",
#           "road_numbers": [],
#           "incident_length_m": 50.4302288577,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Cahill Expressway",
#           "to": "Alfred Street N",
#           "road_numbers": [],
#           "incident_length_m": 47.8945492753,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Clark Road (High Street)",
#           "to": "Alfred Street (High Street)",
#           "road_numbers": [],
#           "incident_length_m": 64.1042765719,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Bridge closed",
#           "from": "Ernest Street",
#           "to": "Warringah Freeway",
#           "road_numbers": [],
#           "incident_length_m": 414.4272066467,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Alfred Street\"",
#           "to": "Bradfield Highway",
#           "road_numbers": [],
#           "incident_length_m": 512.2873695073,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Falcon Street Exit (A8)",
#           "to": "Ernest Street",
#           "road_numbers": [],
#           "incident_length_m": 80.3454301624,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Ernest Street Exit",
#           "to": "Naremburn\"",
#           "road_numbers": [],
#           "incident_length_m": 846.8959612032,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Miller Street (Warringah Freeway/M1)",
#           "to": "Falcon Street (Warringah Freeway/M1)",
#           "road_numbers": [
#             "M1"
#           ],
#           "incident_length_m": 880.2451827724,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Alfred Street\"",
#           "to": "Cahill Expressway",
#           "road_numbers": [],
#           "incident_length_m": 1047.7515026552,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "Page Street / Holloway Street",
#           "to": "Page Street",
#           "road_numbers": [],
#           "incident_length_m": 234.663782897,
#           "incident_delay": 311,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 6,
#           "description": "Stationary traffic",
#           "from": "William Street",
#           "to": "Sir John Young Crescent",
#           "road_numbers": [],
#           "incident_length_m": 314.3993411548,
#           "incident_delay": 187,
#           "incident_magnitude_delay": 3
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Heffron Road",
#           "to": "Tingwell Boulevard",
#           "road_numbers": [],
#           "incident_length_m": 10.8506803557,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Driver Avenue",
#           "to": "Moore Park",
#           "road_numbers": [],
#           "incident_length_m": 101.2674494946,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Bunnerong Road",
#           "to": "Marville Avenue",
#           "road_numbers": [],
#           "incident_length_m": 27.0093681212,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Marine Parade",
#           "to": "Fenton Avenue",
#           "road_numbers": [],
#           "incident_length_m": 89.2150046646,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 8,
#           "description": "Closed",
#           "from": "Parsley Road",
#           "to": "Hopetoun Avenue",
#           "road_numbers": [],
#           "incident_length_m": 79.0849979967,
#           "incident_delay": null,
#           "incident_magnitude_delay": 4
#         },
#         {
#           "category": 9,
#           "description": "Roadworks",
#           "from": "Barrenjoey Road",
#           "to": "Avalon Parade",
#           "road_numbers": [],
#           "incident_length_m": 33.6246872835,
#           "incident_delay": null,
#           "incident_magnitude_delay": 0
#         }
#       ],
#       "segment": {
#         "inbound": {
#           "from": "dubbo",
#           "to": "sydney",
#           "duration_sec": 20607,
#           "distance_m": 401744
#         },
#         "outbound": null,
#         "cumulative_time_to_here_sec": 57734,
#         "remaining_time_from_here_sec": 0
#       },
#       "route_travel": {
#         "total_duration_sec": 57734,
#         "distance_meters": 1218183,
#         "leg_durations_sec": [
#           8466,
#           28661,
#           20607
#         ],
#         "leg_distances_meters": [
#           178743,
#           637696,
#           401744
#         ]
#       }
#     },
#     "__route_summary__": {
#       "total_duration_sec": 57734,
#       "total_distance_meters": 1218183,
#       "num_waypoints": 2
#     }
#   }
# }

# %%
def process_data(raw_data: dict) -> pd.DataFrame:
    """
    Processes the raw nested dictionary, creating a detailed record for each
    traffic incident, combined with the weather data for that location.
    """
    print("--- Starting data processing and feature engineering ---")
    
    incident_records = []
    
    # Loop through the nested structure
    for route_name, locations in raw_data.items():
        for location_name, data in locations.items():
            
            weather_info = data.get('weather', {})
            traffic_incidents = data.get('traffic', [])

            # If there are no traffic incidents, we can skip or create a record with no incident info
            if not isinstance(traffic_incidents, list) or not traffic_incidents:
                continue

            # --- Create a new row for EACH traffic incident ---
            for incident in traffic_incidents:
                # --- Weather Feature Engineering ---
                try:
                    rainfall = float(weather_info.get('rainfall_since_9am', 0.0))
                except (ValueError, TypeError):
                    rainfall = 0.0

                # --- Time Feature Engineering ---
                record_time_utc_str = weather_info.get('time_utc')
                record_dt, day_of_week, hour_of_day = None, None, None
                if record_time_utc_str:
                    try:
                        record_dt = datetime.strptime(record_time_utc_str, '%Y%m%d%H%M%S')
                        day_of_week = record_dt.weekday()
                        hour_of_day = record_dt.hour
                    except ValueError:
                        pass

                # Create a dictionary for this single incident record
                record = {
                    'timestamp': record_dt,
                    'route': route_name,
                    'from_location': location_name,
                    'temperature': weather_info.get('temperature'),
                    'is_raining': rainfall > 0.1,
                    'wind_speed_kmh': weather_info.get('wind_speed_kmh'),
                    'day_of_week': day_of_week,
                    'hour_of_day': hour_of_day,
                    # --- Add specific incident details ---
                    'incident_category': incident.get('category'),
                    'incident_description': incident.get('description'),
                    'incident_from': incident.get('from'),
                    'incident_to': incident.get('to'),
                    'incident_length_m': incident.get('incident_length_m'),
                    #'incident_delay_sec': incident.get('incident_delay'),
                    'incident_magnitude_delay': incident.get('incident_magnitude_delay'),
                    'total_distance_meters':route_travel.get('distance_meters'),
                    'total_time_sec':route_travel.get('total_duration_sec')

                }
                incident_records.append(record)

    # Create a Pandas DataFrame from the list of incident records
    df = pd.DataFrame(incident_records)
    
    # Set the timestamp as the index for time-series analysis
    if 'timestamp' in df.columns:
        df = df.set_index('timestamp')
    
    print("--- Data processing complete! ---")
    return df

# %%
import pandas as pd
import math
from datetime import datetime

def build_leg_level_df(all_data: dict) -> pd.DataFrame:
    """
    ONE row per leg: (route, from_node -> to_node).
    Incident impact is attributed to the outbound leg of the node whose bbox we queried.
    """
    rows = []

    now = datetime.now()
    dow = now.weekday()
    hour = now.hour

    for route, locations in all_data.items():
        summary = locations.get("__route_summary__", {}) or {}
        total_sec = summary.get("total_duration_sec")
        total_m   = summary.get("total_distance_meters")

        # Gather nodes with ordering by cumulative time so legs line up
        nodes = []
        for node, payload in locations.items():
            if node == "__route_summary__":
                continue
            seg = (payload.get("segment") or {})
            nodes.append({
                "name": node,
                "cum_sec": seg.get("cumulative_time_to_here_sec"),
                "payload": payload,
                "seg": seg
            })
        nodes = sorted(nodes, key=lambda r: r["cum_sec"] if r["cum_sec"] is not None else math.inf)

        # Build leg rows (node i -> node i+1)
        for i in range(len(nodes) - 1):
            from_node = nodes[i]
            to_node   = nodes[i + 1]

            seg = from_node["seg"] or {}
            outb = seg.get("outbound") or {}
            base_leg_sec = outb.get("duration_sec")
            base_leg_m   = outb.get("distance_m")

            # incidents fetched for the FROM node's bbox → attribute to this outbound leg
            traffic = from_node["payload"].get("traffic") or []
            if isinstance(traffic, dict):  # normalize "No incidents" / error shape
                traffic_list = []
            else:
                traffic_list = traffic

            # simple aggregates; TomTom 'delay' is seconds when present
            inc_cnt = len(traffic_list)
            inc_delay_sum = sum(
                max(0, (inc.get("incident_delay") or 0)) for inc in traffic_list
                if isinstance(inc, dict)
            )
            inc_len_sum_m = sum(
                max(0.0, float(inc.get("incident_length_m") or 0.0)) for inc in traffic_list
                if isinstance(inc, dict)
            )

            weather = from_node["payload"].get("weather") or {}

            rows.append({
                # keys
                "timestamp": now,
                "route": route,
                "leg_index": i,
                "from_node": from_node["name"],
                "to_node": to_node["name"],

                # route context
                "route_total_duration_sec": total_sec,
                "route_total_distance_m": total_m,

                # base leg metrics (from router)
                "leg_base_duration_sec": base_leg_sec,
                "leg_base_distance_m": base_leg_m,

                # incident aggregates mapped to this leg
                "leg_incident_count": inc_cnt,
                "leg_incident_delay_sum_sec": inc_delay_sum,
                "leg_incident_length_sum_m": inc_len_sum_m,

                # adjusted target (what you’d model if you want incident impact)
                "leg_total_duration_sec": (
                    (base_leg_sec or 0) + inc_delay_sum if base_leg_sec is not None else None
                ),

                # weather at the FROM node (you can add destination weather too if needed)
                "wx_location": weather.get("location"),
                "wx_time_utc": weather.get("time_utc"),
                "wx_temp_c": weather.get("temperature"),
                "wx_rain_mm": weather.get("rainfall_since_9am"),
                "wx_wind_kmh": weather.get("wind_speed_kmh"),
                "wx_wind_dir": weather.get("wind_direction"),

                # time features
                "day_of_week": dow,
                "hour_of_day": hour,
            })

    df = pd.DataFrame(rows)
    if "timestamp" in df.columns:
        df = df.set_index("timestamp")

    # optional: engineered helpers
    if "leg_base_distance_m" in df.columns:
        df["leg_distance_km"] = df["leg_base_distance_m"] / 1000.0
    if "leg_total_duration_sec" in df.columns:
        df["leg_total_duration_hr"] = df["leg_total_duration_sec"] / 3600.0

    return df

# %%
df = build_leg_level_df(all_data)

# %%
df['total_time_hr'] = df['total_time_sec']/3600
df['total_distance_km'] = df['total_distance_meters']/1000

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                                    route  leg_index   from_node     to_node  \
# timestamp
# 2025-08-12 18:03:48.768228  Hume_Highway          0   melbourne      albury
# 2025-08-12 18:03:48.768228  Hume_Highway          1      albury    goulburn
# 2025-08-12 18:03:48.768228  Hume_Highway          2    goulburn      sydney
# 2025-08-12 18:03:48.768228  Inland_Route          0   melbourne  shepparton
# 2025-08-12 18:03:48.768228  Inland_Route          1  shepparton       dubbo
#
#                             route_total_duration_sec  route_total_distance_m  \
# timestamp
# 2025-08-12 18:03:48.768228                     37561                  867226
# 2025-08-12 18:03:48.768228                     37561                  867226
# 2025-08-12 18:03:48.768228                     37561                  867226
# 2025-08-12 18:03:48.768228                     57734                 1218183
# 2025-08-12 18:03:48.768228                     57734                 1218183
#
#                             leg_base_duration_sec  leg_base_distance_m  \
# timestamp
# 2025-08-12 18:03:48.768228                  13826               313516
# 2025-08-12 18:03:48.768228                  14950               357845
# 2025-08-12 18:03:48.768228                   8784               195864
# 2025-08-12 18:03:48.768228                   8466               178743
# 2025-08-12 18:03:48.768228                  28661               637696
#
#                             leg_incident_count  leg_incident_delay_sum_sec  \
# timestamp
# 2025-08-12 18:03:48.768228                 110                        4112
# 2025-08-12 18:03:48.768228                   2                           0
# 2025-08-12 18:03:48.768228                   4                         536
# 2025-08-12 18:03:48.768228                 110                        4112
# 2025-08-12 18:03:48.768228                   2                           0
#
#                             leg_incident_length_sum_m  leg_total_duration_sec  \
# timestamp
# 2025-08-12 18:03:48.768228               65841.264807                   17938
# 2025-08-12 18:03:48.768228                 429.132801                   14950
# 2025-08-12 18:03:48.768228               16670.217053                    9320
# 2025-08-12 18:03:48.768228               65841.264807                   12578
# 2025-08-12 18:03:48.768228                 357.135651                   28661
#
#                                          wx_location     wx_time_utc  \
# timestamp
# 2025-08-12 18:03:48.768228  Melbourne (Olympic Park)  20250812073000
# 2025-08-12 18:03:48.768228                      None            None
# 2025-08-12 18:03:48.768228                  Canberra  20250812073000
# 2025-08-12 18:03:48.768228  Melbourne (Olympic Park)  20250812073000
# 2025-08-12 18:03:48.768228                Shepparton  20250812073000
#
#                             wx_temp_c wx_rain_mm  wx_wind_kmh wx_wind_dir  \
# timestamp
# 2025-08-12 18:03:48.768228       10.8        3.0         13.0           N
# 2025-08-12 18:03:48.768228        NaN       None          NaN        None
# 2025-08-12 18:03:48.768228       11.0        0.0         11.0         NNW
# 2025-08-12 18:03:48.768228       10.8        3.0         13.0           N
# 2025-08-12 18:03:48.768228       11.7        0.0          9.0         ENE
#
#                             day_of_week  hour_of_day  leg_distance_km  \
# timestamp
# 2025-08-12 18:03:48.768228            1           18          313.516
# 2025-08-12 18:03:48.768228            1           18          357.845
# 2025-08-12 18:03:48.768228            1           18          195.864
# 2025-08-12 18:03:48.768228            1           18          178.743
# 2025-08-12 18:03:48.768228            1           18          637.696
#
#                             leg_total_duration_hr
# timestamp
# 2025-08-12 18:03:48.768228               4.982778
# 2025-08-12 18:03:48.768228               4.152778
# 2025-08-12 18:03:48.768228               2.588889
# 2025-08-12 18:03:48.768228               3.493889
# 2025-08-12 18:03:48.768228               7.961389
